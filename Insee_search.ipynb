# %% [markdown]
# # Search in the INSEE database
#
# The code here-in-below shows how to search in the csv file from INSEE after they have been formatted in Insee_formatting.ipynb.
# Various methods to look for data are timed and compared
#
# Dr. M. Fortin, Sept. 2020

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### List of formatted csv in the zip file obtained as explained in Insee_formatting.ipynb

# %%
from zipfile import ZipFile
zip_file = ZipFile('Insee.zip')
file_name=[text_file.filename for text_file in zip_file.infolist()]
print(file_name)
# Out:
# ['Insee_00s.csv', 'Insee_10s.csv', 'Insee_70s.csv', 'Insee_80s.csv', 'Insee_90s.csv']

# %% [markdown]
# # 1. French presidents

# %% [markdown]
# ## 1.1 Georges Pompidou

# %%
nom_recherche="Pompidou"
prenom_recherche="Georges"
genre="1" # only male presidents so far :(
decade='70s'

# %%
insee = pd.DataFrame()
insee=pd.read_csv(zip_file.open(file_name[file_name.index('Insee_'+decade+'.csv')]),dtype=str, index_col=0) 
insee
# Out:
#                  nom                   prenoms sexe journaiss moisnaiss  \
# 0             DUCRET          MARIE ANTOINETTE    2        09        01
# 1           GRANGEON            ERIC JEAN REMY    1        29        03
# 2             VELLET                  PHILIPPE    1        01        02
# 3          PRESSAVIN                     LYDIE    2        06        04
# 4              DOUAT      MARIE-SYLVIA MARTINE    2        08        07
# ...              ...                       ...  ...       ...       ...
# 3329654      LOUBEAU  NADEGE CATHERINE PASCALE    2        12        06
# 3329655        DENEL         YASMINE ALEXANDRA    2        17        05
# 3329656  WEISSENSEEL                    CELINE    2        20        02
# 3329657       GUSTAN                JEAN-LOUIS    1        09        05
# 3329658       FISTON          ANNICK FREDERINE    2        24        07
#
#         anneenaiss lieunaiss          commnaiss paysnaiss jourdeces moisdeces  \
# 0             1922     01004  AMBERIEU-EN-BUGEY    FRANCE        10        12
# 1             1969     01004  AMBERIEU-EN-BUGEY    FRANCE        25        04
# 2             1970     01004  AMBERIEU-EN-BUGEY    FRANCE        03        02
# 3             1970     01004  AMBERIEU-EN-BUGEY    FRANCE        06        04
# 4             1970     01004  AMBERIEU-EN-BUGEY    FRANCE        08        07
# ...            ...       ...                ...       ...       ...       ...
# 3329654       1971     95680    VILLIERS-LE-BEL    FRANCE        04        02
# 3329655       1977     95680    VILLIERS-LE-BEL    FRANCE        25        12
# 3329656       1979     95680    VILLIERS-LE-BEL    FRANCE        22        02
# 3329657       1979     95680    VILLIERS-LE-BEL    FRANCE        05        09
# 3329658       1979     95680    VILLIERS-LE-BEL    FRANCE        30        09
#
#         anneedeces lieudeces actedeces
# 0             1970     01421         6
# 1             1970     69383      1059
# 2             1970     01004        12
# 3             1970     01004        33
# 4             1970     01053       457
# ...            ...       ...       ...
# 3329654       1979     75114       421
# 3329655       1979     60175       348
# 3329656       1979     93048       164
# 3329657       1979     95500       390
# 3329658       1979     95277       531
#
# [3329659 rows x 14 columns]

# %% [markdown]
# #### Columns
# 1. nom: family name
# 2. prenom(s): first name(s)
# 3. sexe: gender 1 for male and 2 for female
# 4. journaiss: day of birth
# 5. monthnaiss: month of birth
# 6. yearnaiss: year of birth
# 7. lieunaiss: postcode of the place of birth
# 8. commnaiss: place of birth
# 9. paysnaiss: country of birth
# 10. jourdeces: day of death
# 11. monthdeces: month of death
# 12. yeardeces: year of death
# 14. lieudeces: postcode of the place of death
# 15. actedeces: reference of the death record

# %% [markdown]
# ### 1.1.1. Time the search for gender

# %% [markdown]
# #### Using where()

# %%
# %%time
insee[insee.sexe.where(insee.sexe==genre).notnull()].head()
# Out:
# CPU times: user 602 ms, sys: 0 ns, total: 602 ms
# Wall time: 601 ms
#          nom         prenoms sexe journaiss moisnaiss anneenaiss lieunaiss  \
# 1   GRANGEON  ERIC JEAN REMY    1        29        03       1969     01004
# 2     VELLET        PHILIPPE    1        01        02       1970     01004
# 5     ROSIER           FELIX    1        25        11       1891     01004
# 6  BOUVEYRON          PIERRE    1        27        04       1900     01005
# 8     GIVORD         JACQUES    1        12        08       1910     01026
#
#              commnaiss paysnaiss jourdeces moisdeces anneedeces lieudeces  \
# 1    AMBERIEU-EN-BUGEY    FRANCE        25        04       1970     69383
# 2    AMBERIEU-EN-BUGEY    FRANCE        03        02       1970     01004
# 5    AMBERIEU-EN-BUGEY    FRANCE        14        11       1970     30012
# 6  AMBERIEUX-EN-DOMBES    FRANCE        11        12       1970     69383
# 8       BAGE-LE-CHATEL    FRANCE        24        11       1970     06088
#
#   actedeces
# 1      1059
# 2        12
# 5        15
# 6      2094
# 8      4880

# %% [markdown]
# #### Using a list comprehension

# %%
# %%time
insee[insee.sexe==genre].head()
# Out:
# CPU times: user 478 ms, sys: 63.8 ms, total: 541 ms
# Wall time: 545 ms
#          nom         prenoms sexe journaiss moisnaiss anneenaiss lieunaiss  \
# 1   GRANGEON  ERIC JEAN REMY    1        29        03       1969     01004
# 2     VELLET        PHILIPPE    1        01        02       1970     01004
# 5     ROSIER           FELIX    1        25        11       1891     01004
# 6  BOUVEYRON          PIERRE    1        27        04       1900     01005
# 8     GIVORD         JACQUES    1        12        08       1910     01026
#
#              commnaiss paysnaiss jourdeces moisdeces anneedeces lieudeces  \
# 1    AMBERIEU-EN-BUGEY    FRANCE        25        04       1970     69383
# 2    AMBERIEU-EN-BUGEY    FRANCE        03        02       1970     01004
# 5    AMBERIEU-EN-BUGEY    FRANCE        14        11       1970     30012
# 6  AMBERIEUX-EN-DOMBES    FRANCE        11        12       1970     69383
# 8       BAGE-LE-CHATEL    FRANCE        24        11       1970     06088
#
#   actedeces
# 1      1059
# 2        12
# 5        15
# 6      2094
# 8      4880

# %% [markdown]
# #### Using Vectorization

# %%
# %%time
f = np.vectorize(lambda haystack, needle: needle in haystack)
insee[f(insee.sexe, genre)].head()
# Out:
# CPU times: user 704 ms, sys: 56.5 ms, total: 761 ms
# Wall time: 774 ms
#          nom         prenoms sexe journaiss moisnaiss anneenaiss lieunaiss  \
# 1   GRANGEON  ERIC JEAN REMY    1        29        03       1969     01004
# 2     VELLET        PHILIPPE    1        01        02       1970     01004
# 5     ROSIER           FELIX    1        25        11       1891     01004
# 6  BOUVEYRON          PIERRE    1        27        04       1900     01005
# 8     GIVORD         JACQUES    1        12        08       1910     01026
#
#              commnaiss paysnaiss jourdeces moisdeces anneedeces lieudeces  \
# 1    AMBERIEU-EN-BUGEY    FRANCE        25        04       1970     69383
# 2    AMBERIEU-EN-BUGEY    FRANCE        03        02       1970     01004
# 5    AMBERIEU-EN-BUGEY    FRANCE        14        11       1970     30012
# 6  AMBERIEUX-EN-DOMBES    FRANCE        11        12       1970     69383
# 8       BAGE-LE-CHATEL    FRANCE        24        11       1970     06088
#
#   actedeces
# 1      1059
# 2        12
# 5        15
# 6      2094
# 8      4880

# %% [markdown]
# #### Conclusion: The list comprehension appears to be the fastest

# %% [markdown]
# ### 1.1.2 Time the search for the family name (nom)

# %% [markdown]
# #### Using a list comprehension

# %%
# %%time
insee[(insee['nom'] == nom_recherche.upper())].head()
# Out:
# CPU times: user 237 ms, sys: 4.05 ms, total: 241 ms
# Wall time: 239 ms
#              nom       prenoms sexe journaiss moisnaiss anneenaiss lieunaiss  \
# 69210   POMPIDOU      FRANCOIS    1        28        11       1893     24049
# 458379  POMPIDOU      BENJAMIN    1        02        06       1930     75104
# 677436  POMPIDOU  GABRIEL JEAN    1        21        04       1916     46038
# 677886  POMPIDOU  ANNE JUSTINE    2        07        03       1895     46117
# 693150  POMPIDOU   HERVE BRUNO    1        18        04       1970     51454
#
#               commnaiss paysnaiss jourdeces moisdeces anneedeces lieudeces  \
# 69210    BORN-DE-CHAMPS    FRANCE        22        04       1971     24497
# 458379          PARIS 4    FRANCE        11        08       1972     25523
# 677436        BRETENOUX    FRANCE        08        01       1973     91174
# 677886  GAGNAC-SUR-CERE    FRANCE        29        03       1973     46038
# 693150            REIMS    FRANCE        06        11       1973     51454
#
#        actedeces
# 69210          1
# 458379         5
# 677436      24/1
# 677886         4
# 693150      1965

# %% [markdown]
# #### Using find()

# %%
# %%time
insee[ insee['nom'].str.find(nom_recherche.upper())==0].head()
# Out:
# CPU times: user 1.99 s, sys: 12.1 ms, total: 2.01 s
# Wall time: 2 s
#              nom       prenoms sexe journaiss moisnaiss anneenaiss lieunaiss  \
# 69210   POMPIDOU      FRANCOIS    1        28        11       1893     24049
# 458379  POMPIDOU      BENJAMIN    1        02        06       1930     75104
# 677436  POMPIDOU  GABRIEL JEAN    1        21        04       1916     46038
# 677886  POMPIDOU  ANNE JUSTINE    2        07        03       1895     46117
# 693150  POMPIDOU   HERVE BRUNO    1        18        04       1970     51454
#
#               commnaiss paysnaiss jourdeces moisdeces anneedeces lieudeces  \
# 69210    BORN-DE-CHAMPS    FRANCE        22        04       1971     24497
# 458379          PARIS 4    FRANCE        11        08       1972     25523
# 677436        BRETENOUX    FRANCE        08        01       1973     91174
# 677886  GAGNAC-SUR-CERE    FRANCE        29        03       1973     46038
# 693150            REIMS    FRANCE        06        11       1973     51454
#
#        actedeces
# 69210          1
# 458379         5
# 677436      24/1
# 677886         4
# 693150      1965

# %% [markdown]
# #### Using match()

# %%
# %%time
insee[insee.nom.str.match(nom_recherche.upper())==True].head()
# Out:
# CPU times: user 1.63 s, sys: 3.87 ms, total: 1.63 s
# Wall time: 1.63 s
#              nom       prenoms sexe journaiss moisnaiss anneenaiss lieunaiss  \
# 69210   POMPIDOU      FRANCOIS    1        28        11       1893     24049
# 458379  POMPIDOU      BENJAMIN    1        02        06       1930     75104
# 677436  POMPIDOU  GABRIEL JEAN    1        21        04       1916     46038
# 677886  POMPIDOU  ANNE JUSTINE    2        07        03       1895     46117
# 693150  POMPIDOU   HERVE BRUNO    1        18        04       1970     51454
#
#               commnaiss paysnaiss jourdeces moisdeces anneedeces lieudeces  \
# 69210    BORN-DE-CHAMPS    FRANCE        22        04       1971     24497
# 458379          PARIS 4    FRANCE        11        08       1972     25523
# 677436        BRETENOUX    FRANCE        08        01       1973     91174
# 677886  GAGNAC-SUR-CERE    FRANCE        29        03       1973     46038
# 693150            REIMS    FRANCE        06        11       1973     51454
#
#        actedeces
# 69210          1
# 458379         5
# 677436      24/1
# 677886         4
# 693150      1965

# %% [markdown]
# #### Conclusion: again the list comprehension is the fastest

# %% [markdown]
# ### 1.1.3. Check if adding the constraint on gender slows down the search

# %% [markdown]
# #### Case A:
# 1. gender
# 2. family name
# 3. first name

# %%
# %%time
insee = pd.DataFrame()
insee=pd.read_csv(zip_file.open(file_name[file_name.index('Insee_'+decade+'.csv')]),dtype=str, index_col=0) 

insee=insee[(insee['nom'] == nom_recherche.upper())]
insee=insee[insee.prenoms.str.contains(prenom_recherche.upper())]
insee=insee[insee.sexe==genre]

insee
# Out:
# CPU times: user 11.2 s, sys: 640 ms, total: 11.9 s
# Wall time: 11.9 s
#              nom               prenoms sexe journaiss moisnaiss anneenaiss  \
# 933471  POMPIDOU  GEORGES JEAN RAYMOND    1        05        07       1911
#
#        lieunaiss   commnaiss paysnaiss jourdeces moisdeces anneedeces  \
# 933471     15129  MONTBOUDIF    FRANCE        02        04       1974
#
#        lieudeces actedeces
# 933471     75104       277

# %% [markdown]
# #### Case B:
# 1. family name
# 2. first name

# %%
# %%time
insee = pd.DataFrame()
insee=pd.read_csv(zip_file.open(file_name[file_name.index('Insee_'+decade+'.csv')]),dtype=str, index_col=0) 

insee=insee[(insee['nom'] == nom_recherche.upper())]
insee=insee[insee.prenoms.str.contains(prenom_recherche.upper())]
insee
# Out:
# CPU times: user 11.4 s, sys: 604 ms, total: 12 s
# Wall time: 12 s
#              nom               prenoms sexe journaiss moisnaiss anneenaiss  \
# 933471  POMPIDOU  GEORGES JEAN RAYMOND    1        05        07       1911
#
#        lieunaiss   commnaiss paysnaiss jourdeces moisdeces anneedeces  \
# 933471     15129  MONTBOUDIF    FRANCE        02        04       1974
#
#        lieudeces actedeces
# 933471     75104       277

# %% [markdown]
# **Conclusion** comparing cases A and B: adding the gender seems to slow down the search a little

# %% [markdown]
# ### 1.1.4. Compare the search order

# %% [markdown]
# #### Case C:
# 1. first name
# 2. family name

# %%
# %%time
insee = pd.DataFrame()
insee=pd.read_csv(zip_file.open(file_name[file_name.index('Insee_'+decade+'.csv')]),dtype=str, index_col=0) 

insee=insee[insee.prenoms.str.contains(prenom_recherche.upper(), na=False)]
insee=insee[(insee['nom'] == nom_recherche.upper())]
insee
# Out:
# CPU times: user 13.1 s, sys: 672 ms, total: 13.8 s
# Wall time: 13.8 s
#              nom               prenoms sexe journaiss moisnaiss anneenaiss  \
# 933471  POMPIDOU  GEORGES JEAN RAYMOND    1        05        07       1911
#
#        lieunaiss   commnaiss paysnaiss jourdeces moisdeces anneedeces  \
# 933471     15129  MONTBOUDIF    FRANCE        02        04       1974
#
#        lieudeces actedeces
# 933471     75104       277

# %% [markdown]
# **Conclusion** comparing cases B and C: family name then first name is faster (the search of the family name is more restrictive than the one of the first name obviously)

# %% [markdown]
# ### 1.1.5. Check if one should combine the searches or do it one by one

# %% [markdown]
# #### Case D: first name & family name simultaneously

# %%
# %%time
insee = pd.DataFrame()
insee=pd.read_csv(zip_file.open(file_name[file_name.index('Insee_'+decade+'.csv')]),dtype=str, index_col=0) 
  
insee[(insee['nom'] == nom_recherche.upper()) &(insee.prenoms.str.contains(prenom_recherche.upper()))]
# Out:
# CPU times: user 15.6 s, sys: 762 ms, total: 16.3 s
# Wall time: 16.5 s
#              nom               prenoms sexe journaiss moisnaiss anneenaiss  \
# 933471  POMPIDOU  GEORGES JEAN RAYMOND    1        05        07       1911
#
#        lieunaiss   commnaiss paysnaiss jourdeces moisdeces anneedeces  \
# 933471     15129  MONTBOUDIF    FRANCE        02        04       1974
#
#        lieudeces actedeces
# 933471     75104       277

# %% [markdown]
# #### Conclusion: comparing cases D and B: non-simultaneous searches are faster

# %% [markdown]
# ### 1.1.6. Conclusions:
# All in all it is faster to:
# * Use list comprehension when possible
# * Do searches one by one, starting with the most restrictive one here the family name

# %% [markdown]
# ## 1.2. Francois Mitterand

# %%
nom_recherche="Mitterrand"
prenom_recherche="Francois"
genre="1"
decade='90s'

# %%
# %%time
insee = pd.DataFrame()
insee=pd.read_csv(zip_file.open(file_name[file_name.index('Insee_'+decade+'.csv')]),dtype=str, index_col=0) 

insee=insee[(insee['nom'] == nom_recherche.upper())]
insee[insee.prenoms.str.contains(prenom_recherche.upper())]
# Out:
# CPU times: user 20.7 s, sys: 1.1 s, total: 21.8 s
# Wall time: 21.8 s
#                 nom                        prenoms sexe journaiss moisnaiss  \
# 3386468  MITTERRAND  FRANCOIS MARIE ADRIEN MAURICE    1        26        10
#
#         anneenaiss lieunaiss commnaiss paysnaiss jourdeces moisdeces  \
# 3386468       1916     16167    JARNAC    FRANCE        08        01
#
#         anneedeces lieudeces actedeces
# 3386468       1996     75107        16

# %% [markdown]
# ## 1.3. Jacques Chirac

# %%
nom_recherche="Chirac"
prenom_recherche="Jacques"
genre="1"
decade='10s'

# %%
# %%time
insee = pd.DataFrame()
insee=pd.read_csv(zip_file.open(file_name[file_name.index('Insee_'+decade+'.csv')]),dtype=str, index_col=0) 

insee=insee[(insee['nom'] == nom_recherche.upper())]
insee[insee.prenoms.str.contains(prenom_recherche.upper())]
# Out:
# CPU times: user 4.58 s, sys: 232 ms, total: 4.81 s
# Wall time: 4.81 s
#             nom       prenoms sexe journaiss moisnaiss anneenaiss lieunaiss  \
# 1114658  CHIRAC  JACQUES RENE    1        29        11       1932     75105
#
#                         commnaiss paysnaiss jourdeces moisdeces anneedeces  \
# 1114658  PARIS 5E  ARRONDISSEMENT    FRANCE        26        09       2019
#
#         lieudeces actedeces
# 1114658     75106       129

# %% [markdown]
# # 2. Other personalities

# %% [markdown]
# ## 2.1. Agnes Varda

# %% [markdown]
# I know that her first name is not necessarily the real one. Hence I use her name and gender for the search

# %%
nom_recherche="Varda"
genre="2"
decade='10s'

# %%
# %%time 
insee = pd.DataFrame()
insee=pd.read_csv(zip_file.open(file_name[file_name.index('Insee_'+decade+'.csv')]),dtype=str, index_col=0) 

insee=insee[insee.sexe==genre]  
insee[(insee['nom'] == nom_recherche.upper())]
# Out:
# CPU times: user 4.63 s, sys: 196 ms, total: 4.83 s
# Wall time: 4.83 s
#           nom  prenoms sexe journaiss moisnaiss anneenaiss lieunaiss  \
# 822313  VARDA  ARLETTE    2        30        05       1928     99131
# 873434  VARDA   HELENE    2        23        08       1924     75116
#
#                         commnaiss paysnaiss jourdeces moisdeces anneedeces  \
# 822313                    IXELLES  BELGIQUE        29        03       2019
# 873434  PARIS 16E  ARRONDISSEMENT    FRANCE        28        04       2019
#
#        lieudeces actedeces
# 822313     75114       670
# 873434     75115      1370

# %% [markdown]
# I know that Agnès Varda was born in Belgium so her civil name was Arlette Varda and she was on May 30, 1928 and passed on March 29, 2019.

# %% [markdown]
# ## 2.2. Francois Truffaut

# %% [markdown]
# I do not know when he passed hence I am checking all files.
# Also I want to find people whose first names start with Francois, hence the use of startwith().
# Finally in French the female name Francoise starts similarly to male name Francois, hence I restrict to male, checking for gender.

# %%
nom_recherche="Truffaut"
prenom_recherche="Francois"
genre="1"

# %%
# %%time
results = pd.DataFrame()
for filename in file_name:
        insee = pd.DataFrame()
        insee = pd.read_csv(zip_file.open(filename),dtype=str, index_col=0) 
        insee=insee[insee['nom'] == nom_recherche.upper()]
        insee=insee[insee.prenoms.str.startswith(prenom_recherche.upper(),na=False)]
        results = pd.concat([results,insee[insee.sexe==genre]])
results
# Out:
# CPU times: user 1min 14s, sys: 3.96 s, total: 1min 18s
# Wall time: 1min 18s
#               nom          prenoms sexe journaiss moisnaiss anneenaiss  \
# 4745581  TRUFFAUT         FRANCOIS    1        24        12       1920
# 2206511  TRUFFAUT  FRANCOIS ROLAND    1        06        02       1932
#
#         lieunaiss commnaiss paysnaiss jourdeces moisdeces anneedeces  \
# 4745581     59512   ROUBAIX    FRANCE        20        07       2008
# 2206511     75117  PARIS 17    FRANCE        21        10       1984
#
#         lieudeces actedeces
# 4745581     71076       675
# 2206511     92051       555

# %% [markdown]
# Since I have no recollection of Truffaut passing in 2008 when I lived in Paris, I conclude that the screen director passed in 1984.

# %% [markdown]
# # 3. My paternal grandfather

# %% [markdown]
# I know his gender obviously and his family name and that he passed in the 70s.

# %%
genre="1"
nom_recherche="FORTIN"
decade='70s'

# %%
insee = pd.DataFrame()
insee=pd.read_csv(zip_file.open(file_name[file_name.index('Insee_'+decade+'.csv')]),dtype=str, index_col=0) 
insee=insee[(insee.nom == nom_recherche.upper())]
fortin=insee[(insee.sexe ==genre)]
fortin
# Out:
#             nom                   prenoms sexe journaiss moisnaiss anneenaiss  \
# 25072    FORTIN          GUY JEAN GILBERT    1        04        08       1948
# 25492    FORTIN       GUY ALEXANDRE ROGER    1        05        07       1947
# 32451    FORTIN               ANDRE LOUIS    1        17        08       1927
# 38316    FORTIN     ELISEE CHARLES JOSEPH    1        19        03       1902
# 48357    FORTIN         ANDRE GASTON RENE    1        10        06       1906
# ...         ...                       ...  ...       ...       ...        ...
# 3283727  FORTIN             GABRIEL FELIX    1        26        01       1899
# 3285664  FORTIN  ROLAND EDOUARD HYACINTHE    1        30        11       1936
# 3293279  FORTIN  ROBERT DESIRE JULES PAUL    1        17        01       1926
# 3308767  FORTIN      JOSEPH PIERRE LUCIEN    1        09        04       1941
# 3310243  FORTIN    GABRIEL JOSEPH AUGUSTE    1        19        09       1908
#
#         lieunaiss             commnaiss paysnaiss jourdeces moisdeces  \
# 25072       83118         SAINT-RAPHAEL    FRANCE        06        05
# 25492       85122                LESSON    FRANCE        28        07
# 32451       03118                GANNAT    FRANCE        09        12
# 38316       08070  BLANZY-LA-SALONNAISE    FRANCE        29        12
# 48357       14102     LE BREUIL-EN-AUGE    FRANCE        08        12
# ...           ...                   ...       ...       ...       ...
# 3283727     78350          LOUVECIENNES    FRANCE        27        01
# 3285664     78521           RIS-ORANGIS    FRANCE        25        11
# 3293279     80024             ARGOEUVES    FRANCE        29        03
# 3308767     85090        LA FLOCELLIERE    FRANCE        18        01
# 3310243     85182             POUZAUGES    FRANCE        18        08
#
#         anneedeces lieudeces actedeces
# 25072         1970     06088      2049
# 25492         1970     36018        54
# 32451         1971     03197        13
# 38316         1971     51105        18
# 48357         1971     14366       527
# ...            ...       ...       ...
# 3283727       1979     22325         6
# 3285664       1979     89024       792
# 3293279       1979     80024         2
# 3308767       1979     79011         3
# 3310243       1979     44109      1473
#
# [293 rows x 14 columns]

# %% [markdown]
# I also know he was born and died in the same departement (territorial subdivision) in Normandy so the citycode (lieunaiss/lieudeces) where he was born starts with 14, 61, 50, 76, 27.

# %%
results = pd.DataFrame()

departement=["14","61","50","76","27"]
for dep in departement:
    results=pd.concat([results,fortin[(fortin.lieunaiss.str.startswith(dep)) & (fortin.lieudeces.str.startswith(dep))]])
results
# Out:
#             nom                       prenoms sexe journaiss moisnaiss  \
# 48357    FORTIN             ANDRE GASTON RENE    1        10        06
# 1313988  FORTIN  BERNARD GEORGES LEOPOLD LEON    1        25        10
# 1314539  FORTIN               RAYMOND CHARLES    1        11        08
# 1714801  FORTIN          ALAIN LUCIEN GEORGES    1        13        05
# 2120975  FORTIN        CHRISTIAN ALAIN CEDRIC    1        12        09
# 2529773  FORTIN          FRANCIS ANDRE VICTOR    1        17        11
# 1512252  FORTIN  FERNAND PIERRE RAYMOND ANDRE    1        13        07
# 1918625  FORTIN         GERARD RAYMOND MICHEL    1        12        01
# 2738546  FORTIN         ADOLPHE HAZAEL EDMOND    1        04        03
# 2738596  FORTIN                  AUGUSTE LEON    1        10        07
# 113445   FORTIN                  VICTOR LOUIS    1        15        04
# 690371   FORTIN           FERNAND PAUL DESIRE    1        09        11
# 1445442  FORTIN              PAUL JOSEPH LEON    1        26        01
# 1851450  FORTIN              RENE FELIX MARIE    1        09        04
# 1852850  FORTIN             THEOPHILE MAURICE    1        18        03
# 2260811  FORTIN     EDOUARD DESIRE LOUIS RENE    1        08        04
# 2668122  FORTIN             JEAN HENRI DESIRE    1        08        09
# 2670064  FORTIN                  ANDRE EUGENE    1        29        11
# 2670222  FORTIN           ANDRE VICTOR JOSEPH    1        26        10
# 484076   FORTIN           JEAN AUGUSTE ALBERT    1        17        12
# 840985   FORTIN        HENRI JULIEN FLORENTIN    1        22        02
# 1219596  FORTIN                   LEON ALFRED    1        10        06
# 1618332  FORTIN              FLORENTIN PIERRE    1        14        11
# 2025814  FORTIN                JOSEPH AUGUSTE    1        06        09
# 2847610  FORTIN                         HENRI    1        31        12
# 263980   FORTIN                  HENRI LUCIEN    1        15        05
# 1757644  FORTIN                    HENRI LEON    1        27        05
# 2168187  FORTIN                  ANDRE ALBERT    1        09        12
# 2575308  FORTIN         MARCEL LUCIEN EMILIEN    1        18        01
# 2997080  FORTIN                    IVAN JULES    1        05        11
# 2997230  FORTIN                    JEAN ROGER    1        04        01
#
#         anneenaiss lieunaiss                 commnaiss paysnaiss jourdeces  \
# 48357         1906     14102         LE BREUIL-EN-AUGE    FRANCE        08
# 1313988       1901     14654    SAINT-PIERRE-SUR-DIVES    FRANCE        17
# 1314539       1908     14762                      VIRE    FRANCE        12
# 1714801       1952     14762                      VIRE    FRANCE        12
# 2120975       1977     14118                      CAEN    FRANCE        05
# 2529773       1918     14464                  NEUVILLE    FRANCE        02
# 1512252       1914     61093                     CHANU    FRANCE        07
# 1918625       1955     61415    SAINT-LEGER-SUR-SARTHE    FRANCE        20
# 2738546       1908     61273                 MENIL-VIN    FRANCE        16
# 2738596       1899     61287      MONTILLY-SUR-NOIREAU    FRANCE        30
# 113445        1908     50263                   LAPENTY    FRANCE        15
# 690371        1909     50636                 VIERVILLE    FRANCE        17
# 1445442       1901     50089               BRUCHEVILLE    FRANCE        18
# 1851450       1904     50456  SAINT-CLEMENT-RANCOUDRAY    FRANCE        28
# 1852850       1906     50636                 VIERVILLE    FRANCE        05
# 2260811       1908     50617               VARENGUEBEC    FRANCE        04
# 2668122       1912     50083               BRICQUEBOSQ    FRANCE        27
# 2670064       1912     50300          LE MESNIL-ADELEE    FRANCE        08
# 2670222       1897     50341                MONTEBOURG    FRANCE        15
# 484076        1905     76540                     ROUEN    FRANCE        22
# 840985        1903     76351                  LE HAVRE    FRANCE        18
# 1219596       1896     76351                  LE HAVRE    FRANCE        23
# 1618332       1902     76539                  ROUELLES    FRANCE        01
# 2025814       1909     76484                    OISSEL    FRANCE        06
# 2847610       1910     76351                  LE HAVRE    FRANCE        24
# 263980        1913     27613   SAINT-VINCENT-DU-BOULAY    FRANCE        12
# 1757644       1902     27292                GOUTTIERES    FRANCE        22
# 2168187       1901     27496          ROSAY-SUR-LIEURE    FRANCE        01
# 2575308       1910     27229                    EVREUX    FRANCE        15
# 2997080       1894     27358             JOUY-SUR-EURE    FRANCE        09
# 2997230       1920     27375                  LOUVIERS    FRANCE        18
#
#         moisdeces anneedeces lieudeces actedeces
# 48357          12       1971     14366       527
# 1313988        10       1975     14118      1588
# 1314539        07       1975     14762       100
# 1714801        04       1976     14118       534
# 2120975        11       1977     14118      1896
# 2529773        11       1978     14118      1898
# 1512252        02       1975     61093         4
# 1918625        06       1976     61001       191
# 2738546        01       1978     61169        23
# 2738596        08       1978     61391        32
# 113445         06       1971     50090        10
# 690371         03       1973     50458         2
# 1445442        12       1975     50509        24
# 1851450        05       1976     50456         3
# 1852850        11       1976     50458         7
# 2260811        02       1977     50343         1
# 2668122        04       1978     50129       279
# 2670064        07       1978     50318         6
# 2670222        01       1978     50341         2
# 484076         10       1972     76540      1796
# 840985         03       1973     76351       475
# 1219596        05       1974     76351       810
# 1618332        01       1975     76351         1
# 2025814        08       1976     76540      1482
# 2847610        09       1978     76351      1546
# 263980         05       1972     27569         7
# 1757644        07       1976     27056       192
# 2168187        11       1977     27016        80
# 2575308        07       1978     27229       500
# 2997080        02       1979     27229       130
# 2997230        09       1979     27375       200

# %% [markdown]
# I also know his first names (prenoms) and the name of his birthplace (commnaiss) but I will keep that secret... All I can say is that my grandfather is indeed in the list just above :)
